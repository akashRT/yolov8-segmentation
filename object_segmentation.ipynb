# %%
import os
home=os.getcwd()
print(home)
# Out:
# /content

# %% [markdown]
# ## **Installing yolo v8**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 12.6 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import yolo
from IPython.display import display, Image

# %% [markdown]
# ### Cloning Ultralytics

# %%
! git clone --q https://github.com/ultralytics/ultralytics.git

# %%
root_path = "/content/drive/MyDrive/Yolo v8 segmentation"

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Yolo v8 segmentation
# Out:
# /content/drive/MyDrive/Yolo v8 segmentation

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Yolo v8 segmentation

# %%
# !ls
# Out:
# data.yaml  objects_data  object_segmentation.ipynb  runs  yolov8s-seg.pt

# %% [markdown]
# ### **CSUTOM TRAINING**

# %%
# !yolo task=segment mode = train model = yolov8s-seg.pt data = data.yaml epochs=200 imgsz=640 save=true
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### VALIDATION

# %%
# !yolo task=segment mode=val model = /content/drive/MyDrive/Yolo_v8_segmentation/runs/segment/train3/weights/best.pt data = data.yaml
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781922 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/Yolo_v8_segmentation/objects_data/valid/labels... 2 images, 0 backgrounds, 0 corrupt: 100% 2/2 [00:00<00:00,  2.89it/s]
# val: New cache created: /content/drive/MyDrive/Yolo_v8_segmentation/objects_data/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.93it/s]
#                    all          2         83      0.531      0.382      0.338       0.24      0.514      0.359      0.298      0.189
#                   auto          2          6          1          0          0          0          1          0          0          0
# ...

# %% [markdown]
# ### PREDICTION

# %%
# !yolo task=segment mode=predict model = /content/drive/MyDrive/Yolo_v8_segmentation/runs/segment/train3/weights/best.pt data = data.yaml conf=0.25 source=/content/drive/MyDrive/Yolo_v8_segmentation/objects_data/test/images save=true
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781922 parameters, 0 gradients
#
# image 1/2 /content/drive/MyDrive/Yolo_v8_segmentation/objects_data/test/images/10_jpg.rf.128254cfed753ef3d450dcbd94bd77e8.jpg: 640x640 1 bike, 6 cars, 6 persons, 21.1ms
# image 2/2 /content/drive/MyDrive/Yolo_v8_segmentation/objects_data/test/images/9_jpg.rf.04f2833e918332bd1df01216ced51b23.jpg: 640x640 6 cars, 21.1ms
# Speed: 2.2ms preprocess, 21.1ms inference, 54.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
